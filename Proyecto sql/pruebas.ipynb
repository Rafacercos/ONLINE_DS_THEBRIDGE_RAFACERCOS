# %%
import pandas as pd
import numpy as np

# %%
clase1 = pd.read_csv("clase_1.csv", sep=";")
clase2 = pd.read_csv("clase_2.csv", sep=";")
clase3 = pd.read_csv("clase_3.csv", sep=";")
clase4 = pd.read_csv("clase_4.csv", sep=";")
profesores = pd.read_csv("claustro.csv", sep=";")
profesores
# Out:
#                Nombre Rol Vertical   Promocion    Campus   Modalidad
# 0           Noa Yáñez  TA       DS  Septiembre    Madrid  Presencial
# 1   Saturnina Benitez  TA       DS  Septiembre    Madrid  Presencial
# 2          Anna Feliu  TA       FS  Septiembre    Madrid  Presencial
# 3       Rosalva Ayuso  TA       FS  Septiembre  Valencia  Presencial
# 4    Ana Sofía Ferrer  TA       FS     Febrero  Valencia  Presencial
# 5     Angélica Corral  TA       FS     Febrero    Madrid  Presencial
# 6         Ariel Lledó  TA       DS  Septiembre    Madrid  Presencial
# 7         Mario Prats  LI       FS     Febrero  Valencia      Online
# 8   Luis Ángel Suárez  LI       FS  Septiembre    Madrid      Online
# 9  María Dolores Diaz  LI       DS  Septiembre    Madrid      Online

# %%
clase1
# Out:
#                   Nombre                           Email   Promoción  \
# 0           Jafet Casals          Jafet_Casals@gmail.com  Septiembre
# 1       Jorge Manzanares      Jorge_Manzanares@gmail.com  Septiembre
# 2          Onofre Adadia         Onofre_Adadia@gmail.com  Septiembre
# 3           Merche Prada          Merche_Prada@gmail.com  Septiembre
# 4           Pilar Abella          Pilar_Abella@gmail.com  Septiembre
# 5           Leoncio Tena          Leoncio_Tena@gmail.com  Septiembre
# 6        Odalys Torrijos       Odalys_Torrijos@gmail.com  Septiembre
# 7       Eduardo Caparrós      Eduardo_Caparrós@gmail.com  Septiembre
# 8     Ignacio Goicoechea    Ignacio_Goicoechea@gmail.com  Septiembre
# 9      Clementina Santos     Clementina_Santos@gmail.com  Septiembre
# 10         Daniela Falcó         Daniela_Falcó@gmail.com  Septiembre
# 11         Abraham Vélez         Abraham_Vélez@gmail.com  Septiembre
# 12  Maximiliano Menéndez  Maximiliano_Menéndez@gmail.com  Septiembre
# ...

# %%
clase1.columns == clase2.columns 

data_science = pd.concat((clase1, clase2))
data_science.index= np.arange(1,26)
data_science
data_science["Nombre"].values
# Out:
# array(['Jafet Casals', 'Jorge Manzanares', 'Onofre Adadia',
#        'Merche Prada', 'Pilar Abella', 'Leoncio Tena', 'Odalys Torrijos',
#        'Eduardo Caparrós', 'Ignacio Goicoechea', 'Clementina Santos',
#        'Daniela Falcó', 'Abraham Vélez', 'Maximiliano Menéndez',
#        'Anita Heredia', 'Eli Casas', 'Guillermo Borrego',
#        'Sergio Aguirre', 'Carlito Carrión', 'Haydée Figueroa',
#        'Chita Mancebo', 'Joaquina Asensio', 'Cristian Sarabia',
#        'Isabel Ibáñez', 'Desiderio Jordá', 'Rosalina Llanos'],
#       dtype=object)

# %%
clase1.columns == clase3.columns
# Out:
# array([ True,  True,  True,  True,  True, False, False, False, False,
#        False])

# %%
tuple(clase3.columns[-5:])
# Out:
# ('Proyecto_WebDev',
#  'Proyecto_FrontEnd',
#  'Proyecto_Backend',
#  'Proyecto_React',
#  'Proyecto_FullSatck')

# %%
clase3.columns == clase4.columns 

full_stack = pd.concat((clase3, clase4))
full_stack.index= np.arange(1,28)

# %%
profesores.index = np.arange(1,11)

# %%
for x in range(1,11):
    print(tuple(profesores.loc[x]))
# Out:
# ('Noa Yáñez', 'TA', 'DS', 'Septiembre', 'Madrid', 'Presencial')
# ('Saturnina Benitez', 'TA', 'DS', 'Septiembre', 'Madrid', 'Presencial')
# ('Anna Feliu', 'TA', 'FS', 'Septiembre', 'Madrid', 'Presencial')
# ('Rosalva Ayuso', 'TA', 'FS', 'Septiembre', 'Valencia', 'Presencial')
# ('Ana Sofía Ferrer', 'TA', 'FS', 'Febrero', 'Valencia', 'Presencial')
# ('Angélica Corral', 'TA', 'FS', 'Febrero', 'Madrid', 'Presencial')
# ('Ariel Lledó', 'TA', 'DS', 'Septiembre', 'Madrid', 'Presencial')
# ('Mario Prats', 'LI', 'FS', 'Febrero', 'Valencia', 'Online')
# ('Luis Ángel Suárez', 'LI', 'FS', 'Septiembre', 'Madrid', 'Online')
# ('María Dolores Diaz', 'LI', 'DS', 'Septiembre', 'Madrid', 'Online')

# %%
('Noa Yáñez', 'TA', 'DS', 'Septiembre', 'Madrid', 'Presencial')
('Saturnina Benitez', 'TA', 'DS', 'Septiembre', 'Madrid', 'Presencial')
('Anna Feliu', 'TA', 'FS', 'Septiembre', 'Madrid', 'Presencial')
('Rosalva Ayuso', 'TA', 'FS', 'Septiembre', 'Valencia', 'Presencial')
('Ana Sofía Ferrer', 'TA', 'FS', 'Febrero', 'Valencia', 'Presencial')
('Angélica Corral', 'TA', 'FS', 'Febrero', 'Madrid', 'Presencial')
('Ariel Lledó', 'TA', 'DS', 'Septiembre', 'Madrid', 'Presencial')
('Mario Prats', 'LI', 'FS', 'Febrero', 'Valencia', 'Online')
('Luis Ángel Suárez', 'LI', 'FS', 'Septiembre', 'Madrid', 'Online')
('María Dolores Diaz', 'LI', 'DS', 'Septiembre', 'Madrid', 'Online')

# %%
lista_vacia= []
for x in profesores["Rol"]:
    lista_vacia.append(x)
lista_vacia
# Out:
# ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'LI', 'LI', 'LI']

# %%
list(profesores["Nombre"])
# Out:
# ['Noa Yáñez',
#  'Saturnina Benitez',
#  'Anna Feliu',
#  'Rosalva Ayuso',
#  'Ana Sofía Ferrer',
#  'Angélica Corral',
#  'Ariel Lledó',
#  'Mario Prats',
#  'Luis Ángel Suárez',
#  'María Dolores Diaz']

# %%
clase1.rename(columns={"Proyecto_HLF":"Proyecto1","Proyecto_EDA":"Proyecto2","Proyecto_BBDD":"Proyecto3","Proyecto_ML":"Proyecto4","Proyecto_Deployment":"Proyecto5"},inplace=True)
clase2.rename(columns={"Proyecto_HLF":"Proyecto1","Proyecto_EDA":"Proyecto2","Proyecto_BBDD":"Proyecto3","Proyecto_ML":"Proyecto4","Proyecto_Deployment":"Proyecto5"},inplace=True)
clase3.rename(columns={"Proyecto_WebDev":"Proyecto1","Proyecto_FrontEnd":"Proyecto2","Proyecto_Backend":"Proyecto3","Proyecto_React":"Proyecto4","Proyecto_FullSatck":"Proyecto5"},inplace=True)
clase4.rename(columns={"Proyecto_WebDev":"Proyecto1","Proyecto_FrontEnd":"Proyecto2","Proyecto_Backend":"Proyecto3","Proyecto_React":"Proyecto4","Proyecto_FullSatck":"Proyecto5"},inplace=True)

# %%
alumnos = pd.concat([clase1,clase2,clase3,clase4],ignore_index=True)
alumnos.index = np.arange(1,53)

# %%
alumnos.index.drop_duplicates()
# Out:
# RangeIndex(start=0, stop=52, step=1)

# %%
dict_clases = {"clase_id":[1,2,3,4,5,6,7,8],"Vertical":["FullStack","FullStack","FullStack","FullStack","Data Science","Data Science","Data Science","Data Science"],"Promoción":["Septiembre","Septiembre","Febrero","Febrero","Septiembre","Septiembre","Febrero","Febrero"],"Campus":["Madrid","Valencia","Madrid","Valencia","Madrid","Valencia","Madrid","Valencia"]}
clase = pd.DataFrame(dict_clases)
clase.set_index("clase_id",inplace=True)

# %%
alumnos.columns
# Out:
# Index(['Nombre', 'Email', 'Promoción', 'Fecha_comienzo', 'Campus', 'Proyecto1',
#        'Proyecto2', 'Proyecto3', 'Proyecto4', 'Proyecto5'],
#       dtype='object')

# %%
alumnos["Nombre"]
for x in range(1,53):
    print(tuple(alumnos[["Nombre","Email"]].loc[x]))

# %%
clase1 = pd.read_csv("clase_1.csv", sep=";")
clase2 = pd.read_csv("clase_2.csv", sep=";")
clase3 = pd.read_csv("clase_3.csv", sep=";")
clase4 = pd.read_csv("clase_4.csv", sep=";")
profesores = pd.read_csv("claustro.csv", sep=";")

# %%
alumnos["Proyecto1"]
for x in range(1,53):
    print(tuple(alumnos[["Proyecto1","Proyecto2","Proyecto3","Proyecto4","Proyecto5"]].loc[x]))

# %%
# Out:
#                   Nombre                           Email   Promoción  \
# 1           Jafet Casals          Jafet_Casals@gmail.com  Septiembre
# 2       Jorge Manzanares      Jorge_Manzanares@gmail.com  Septiembre
# 3          Onofre Adadia         Onofre_Adadia@gmail.com  Septiembre
# 4           Merche Prada          Merche_Prada@gmail.com  Septiembre
# 5           Pilar Abella          Pilar_Abella@gmail.com  Septiembre
# 6           Leoncio Tena          Leoncio_Tena@gmail.com  Septiembre
# 7        Odalys Torrijos       Odalys_Torrijos@gmail.com  Septiembre
# 8       Eduardo Caparrós      Eduardo_Caparrós@gmail.com  Septiembre
# 9     Ignacio Goicoechea    Ignacio_Goicoechea@gmail.com  Septiembre
# 10     Clementina Santos     Clementina_Santos@gmail.com  Septiembre
# 11         Daniela Falcó         Daniela_Falcó@gmail.com  Septiembre
# 12         Abraham Vélez         Abraham_Vélez@gmail.com  Septiembre
# 13  Maximiliano Menéndez  Maximiliano_Menéndez@gmail.com  Septiembre
# ...

# %%
x = [1,2,3,4]
y = [1,2,3,4]
z = [1,2]
w = [1,2,3]
