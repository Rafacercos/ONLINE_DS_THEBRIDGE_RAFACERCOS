# %%
import pandas as pd

# %%
df = pd.read_csv("61491.csv",sep = ";")

# %%
df
# Out:
#     Comunidades y ciudades autónomas de defunción         Sexo  \
# 0                                           Total  Ambos sexos
# 1                                           Total  Ambos sexos
# 2                                           Total  Ambos sexos
# 3                                           Total  Ambos sexos
# 4                                           Total  Ambos sexos
# ..                                            ...          ...
# 955                                       Melilla      Mujeres
# 956                                       Melilla      Mujeres
# 957                                       Melilla      Mujeres
# 958                                       Melilla      Mujeres
# 959                                       Melilla      Mujeres
#
#                    Edad    Total
# 0      Todas las edades    4.227
# 1    Menores de 15 años   12.000
# 2       De 15 a 29 años  341.000
# 3       De 30 a 39 años  436.000
# 4       De 40 a 44 años  350.000
# ...

# %%
df.head(20)
# Out:
#    Comunidades y ciudades autónomas de defunción         Sexo  \
# 0                                          Total  Ambos sexos
# 1                                          Total  Ambos sexos
# 2                                          Total  Ambos sexos
# 3                                          Total  Ambos sexos
# 4                                          Total  Ambos sexos
# 5                                          Total  Ambos sexos
# 6                                          Total  Ambos sexos
# 7                                          Total  Ambos sexos
# 8                                          Total  Ambos sexos
# 9                                          Total  Ambos sexos
# 10                                         Total  Ambos sexos
# 11                                         Total  Ambos sexos
# 12                                         Total  Ambos sexos
# 13                                         Total  Ambos sexos
# ...
