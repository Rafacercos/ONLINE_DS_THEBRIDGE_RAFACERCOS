# %% [markdown]
# # Ejercicio: Extracción de noticias con Mediastack API
#
# **Objetivo**:
# Escribir un script en Python que recupere noticias de **antena3** y **lasextanoticias** del día de cumpleaños del alumno en 2024 usando Mediastack API, y las almacene en un archivo CSV con los campos requeridos.
#
# ---
#
# ## Enunciado
#
# 1. **Registro en Mediastack**:
#    - Obtén una clave de API gratuita registrándote en [mediastack.com](https://mediastack.com/).
#
# 2. **Requisitos del Script**:
#    - Utiliza la API de Mediastack para recuperar noticias de las fuentes `antena3` y `lasextanoticias`.
#    - Filtra las noticias por el **día de tu cumpleaños en 2024** (formato de fecha: `YYYY-MM-DD`).
#    - Combina los resultados de ambas fuentes en una única tabla.
#    - Guarda la tabla en un archivo CSV con las columnas:
#      `autor`, `titulo`, `descripcion`, `url`, `fuente`, `fechapublicacion`.
#
# 3. **Especificaciones Técnicas**:
#    - Usa la librería `requests` para llamar a la API.
#    - Usa `pandas` para estructurar los datos y guardar el CSV.
#    - Encapsúlalo en un script
#
# Cuidado tienes solo 100 llamadas!

# %%
import requests
import pandas as pd

# %%
url = "http://api.mediastack.com/v1/news?access_key=5de7eb8807d19d7976f5d23a3b80ef0c&limit=150"
parametros = {
    "access_key": "5de7eb8807d19d7976f5d23a3b80ef0c",
    "languages": "en",
    "limit": 100,
    "date_from": "2024-05-11",
    "date_to": "2024-05-12" 
}
response = requests.get(url,params=parametros)

# %%
response
# Out:
# <Response [200]>

# %%
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error{response.status_code}:{response.text}")
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 10000}, 'data': [{'author': 'AP News', 'title': 'Valieva’s attorneys accuse WADA of ‘procedural fraud,’ ask court to revisit her doping case', 'description': 'Attorneys for Russian figure skater Kamila Valieva are taking her doping case back to court, arguing the World Anti-Doping Agency withheld and altered evidence that could have proven her contamination claim during the hearing that resulted in her four-year suspension. The experiment conducted by scientist Martial Saugy at the request of Russia’s anti-doping agency through [&#8230;]', 'url': 'https://www.mymotherlode.com/sports/top-sports-general-news/3693351/valievas-attorneys-accuse-wada-of-procedural-fraud-ask-court-to-revisit-her-doping-case.html', 'source': 'mymotherlode', 'image': None, 'category': 'general', 'language': 'en', 'country': 'us', 'published_at': '2025-03-27T16:14:47+00:00'}, {'author': 'Andrew Liszewski', 'title': 'Audio-Technica’s R2-D2 earbuds play beeps and bloops for audio alerts', 'description': 'Audio-Technica is releasing four Star Wars-themed versions of its ATH-CKS50TW2 earbuds. | Image: Audio-TechnicaAhead of Star Wars Celebration Japan getting underway on April 18th in Tokyo, Audio-Technica has announced four new limited edition versions of its ATH-CKS50TW2 wireless earbuds that originally debuted at CES 2025. Functionality is the same, but the earbuds have gotten a Star Wars-themed makeover with new colors and details inspired by R2-D2, Grogu, the Mandalorian, and Darth Vader plus custom audio alerts that play sound effects like Vader’s ominous labored breathing or a sad...', 'url': 'https://www.theverge.com/news/637222/audio-technica-star-wars-celebration-japan-wireless-earbuds', 'source': 'The Verge', 'image': None, 'category': 'technology', 'language': 'en', 'country': 'us', 'published_at': '2025-03-27T16:14:45+00:00'}, {'author': 'Robert Cumber', 'title': "Selling my house: 7 of the best ways to quickly get your house ready for sale if you're in a hurry", 'description': 'There are some surprisingly easy ways to get your house looking its best for potential buyers', 'url': 'https://www.harrogateadvertiser.co.uk/lifestyle/homes-and-gardens/7-of-the-best-tips-to-quickly-get-your-house-ready-to-sell-5055033', 'source': 'ripongazette', 'image': 'https://www.harrogateadvertiser.co.uk/jpim-static/image/2025/03/27/16/51/onecms_26255061-d756-493b-a068-629b90cae0e3.jpeg?width=1200&auto=webp&crop=3%3A2', 'category': 'general', 'language': 'en', 'country': 'uk', 'published_at': '2025-03-27T16:14:43+00:00'}, {'author': 'Robert Cumber', 'title': "Selling my house: 7 of the best ways to quickly get your house ready for sale if you're in a hurry", 'description': 'There are some surprisingly easy ways to get your house looking its best for potential buyers', 'url': 'https://www.sunderlandecho.com/lifestyle/homes-and-gardens/7-of-the-best-tips-to-quickly-get-your-house-ready-to-sell-5055033', 'source': 'sunderlandecho', 'image': 'https://www.sunderlandecho.com/jpim-static/image/2025/03/27/16/51/onecms_26255061-d756-493b-a068-629b90cae0e3.jpeg?width=1200&auto=webp&crop=3%3A2', 'category': 'general', 'language': 'en', 'country': 'us', 'published_at': '2025-03-27T16:14:43+00:00'}, {'author': 'Robert Cumber', 'title': "Selling my house: 7 of the best ways to quickly get your house ready for sale if you're in a hurry", 'description': 'There are some surprisingly easy ways to get your house looking its best for potential buyers', 'url': 'https://www.sussexexpress.co.uk/lifestyle/homes-and-gardens/7-of-the-best-tips-to-quickly-get-your-house-ready-to-sell-5055033', 'source': 'hastingsobserver', 'image': 'https://www.sussexexpress.co.uk/jpim-static/image/2025/03/27/16/51/onecms_26255061-d756-493b-a068-629b90cae0e3.jpeg?width=1200&auto=webp&crop=3%3A2', 'category': 'general', 'language': 'en', 'country': 'uk', 'published_at': '2025-03-27T16:14:43+00:00'}, {'author': 'Tim Lynch', 'title': 'Mina Kime ...

# %%
noticias = {
    "autor": [],
    "titulo":[],
    "descripcion":[],
    "url":[],
    "fuente":[],
    "fecha":[]
}

# %%
lista_vacia = []
for noticia in data["data"]:
    for caracteristica in noticia.items():
        lista_vacia.append(caracteristica)

# %%
lista_vacia_2 = []
lista_autores = lista_vacia[::10]
for i in lista_autores:
    for autor in i:
        lista_vacia_2.append(autor)

# %%
lista_autores_final = lista_vacia_2[1::2]

# %%
noticias["autor"] = lista_autores_final

# %%
lista_titulos = lista_vacia[1::10]

# %%
lista_vacia_3 = []
for i in lista_titulos:
    for titulo in i:
        lista_vacia_3.append(titulo)

# %%
noticias["titulo"]=lista_vacia_3[1::2]

# %%
lista_descripciones = lista_vacia[2::10]

# %%
#Me doy cuenta de que todo esto se podría hacer mas sencillo y con un único bucle

# %%
lista_vacia_4 = [] 
for i in lista_descripciones:
    for descripcion in i:
        lista_vacia_4.append(descripcion)

# %%
noticias["descripcion"] = lista_vacia_4[1::2]

# %%
lista_url = lista_vacia[3::10]

# %%
lista_vacia_5 =[]
for i in lista_url:
    for url in i:
        lista_vacia_5.append(url)

# %%
noticias["url"]= lista_vacia_5[1::2]

# %%
lista_fuente = lista_vacia[4::10]

# %%
lista_vacia_6 =[]
for i in lista_fuente:
    for fuente in i:
        lista_vacia_6.append(fuente)

# %%
noticias["fuente"]= lista_vacia_6[1::2]

# %%
lista_vacia
# Out:
# [('author', 'AP News'),
#  ('title',
#   'Valieva’s attorneys accuse WADA of ‘procedural fraud,’ ask court to revisit her doping case'),
#  ('description',
#   'Attorneys for Russian figure skater Kamila Valieva are taking her doping case back to court, arguing the World Anti-Doping Agency withheld and altered evidence that could have proven her contamination claim during the hearing that resulted in her four-year suspension. The experiment conducted by scientist Martial Saugy at the request of Russia’s anti-doping agency through [&#8230;]'),
#  ('url',
#   'https://www.mymotherlode.com/sports/top-sports-general-news/3693351/valievas-attorneys-accuse-wada-of-procedural-fraud-ask-court-to-revisit-her-doping-case.html'),
#  ('source', 'mymotherlode'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:14:47+00:00'),
#  ('author', 'Andrew Liszewski'),
#  ('title',
#   'Audio-Technica’s R2-D2 earbuds play beeps and bloops for audio alerts'),
#  ('description',
#   'Audio-Technica is releasing four Star Wars-themed versions of its ATH-CKS50TW2 earbuds. | Image: Audio-TechnicaAhead of Star Wars Celebration Japan getting underway on April 18th in Tokyo, Audio-Technica has announced four new limited edition versions of its ATH-CKS50TW2 wireless earbuds that originally debuted at CES 2025. Functionality is the same, but the earbuds have gotten a Star Wars-themed makeover with new colors and details inspired by R2-D2, Grogu, the Mandalorian, and Darth Vader plus custom audio alerts that play sound effects like Vader’s ominous labored breathing or a sad...'),
#  ('url',
#   'https://www.theverge.com/news/637222/audio-technica-star-wars-celebration-japan-wireless-earbuds'),
#  ('source', 'The Verge'),
#  ('image', None),
#  ('category', 'technology'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:14:45+00:00'),
#  ('author', 'Robert Cumber'),
#  ('title',
#   "Selling my house: 7 of the best ways to quickly get your house ready for sale if you're in a hurry"),
#  ('description',
#   'There are some surprisingly easy ways to get your house looking its best for potential buyers'),
#  ('url',
#   'https://www.harrogateadvertiser.co.uk/lifestyle/homes-and-gardens/7-of-the-best-tips-to-quickly-get-your-house-ready-to-sell-5055033'),
#  ('source', 'ripongazette'),
#  ('image',
#   'https://www.harrogateadvertiser.co.uk/jpim-static/image/2025/03/27/16/51/onecms_26255061-d756-493b-a068-629b90cae0e3.jpeg?width=1200&auto=webp&crop=3%3A2'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'uk'),
#  ('published_at', '2025-03-27T16:14:43+00:00'),
#  ('author', 'Robert Cumber'),
#  ('title',
#   "Selling my house: 7 of the best ways to quickly get your house ready for sale if you're in a hurry"),
#  ('description',
#   'There are some surprisingly easy ways to get your house looking its best for potential buyers'),
#  ('url',
#   'https://www.sunderlandecho.com/lifestyle/homes-and-gardens/7-of-the-best-tips-to-quickly-get-your-house-ready-to-sell-5055033'),
#  ('source', 'sunderlandecho'),
#  ('image',
#   'https://www.sunderlandecho.com/jpim-static/image/2025/03/27/16/51/onecms_26255061-d756-493b-a068-629b90cae0e3.jpeg?width=1200&auto=webp&crop=3%3A2'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:14:43+00:00'),
#  ('author', 'Robert Cumber'),
#  ('title',
#   "Selling my house: 7 of the best ways to quickly get your house ready for sale if you're in a hurry"),
#  ('description',
#   'There are some surprisingly easy ways to get your house looking its best for potential buyers'),
#  ('url',
#   'https://www.sussexexpress.co.uk/lifestyle/homes-and-gardens/7-of-the-best-tips-to-quickly-get-your-house-ready-to-sell-5055033'),
#  ('source', 'hastingsobserver'),
#  ('image',
#   'https://www.sussexexpress.co.uk/jpim-static/image/2025/03/27/16/51/onecms_26255061-d756-493b-a068-629b90cae0e3.jpeg?width=1200&auto=webp&crop=3%3A2'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'uk'),
#  ('published_at', '2025-03-27T16:14:43+00:00'),
#  ('author', 'Tim Lynch'),
#  ('title', 'Mina Kimes on the Broncos: ‘They are a good football team’'),
#  ('description',
#   'Kirby Lee-Imagn Images The Denver Broncos are starting to bring along some believers in the mainstream. Mina Kimes is definitely on board. What a difference a year makes. This time last year, no one thought the Denver Broncos roster was on the rise. They had an excellent 2024 NFL Draft, but it took a season for national media to become believers in Bo Nix. However, it wasn’t just the quarterback play that rose. Guys like Nik Bonitto and Marvin Mims Jr. also broke out, added with perennial stars like Patrick Surtain II winning Defensive Play of the Year. It was a total reversal for a franchise...'),
#  ('url',
#   'https://www.milehighreport.com/2025/3/27/24395240/denver-broncos-really-good-roster-mina-kimes'),
#  ('source', 'milehighreport'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:14:42+00:00'),
#  ('author', 'Chris Roush'),
#  ('title', 'WSJ hires Wells as executive production editor'),
#  ('description',
#   'Wall Street Journal editor in chief\xa0Emma Tucker\xa0sent out the following: I am delighted to announce that\xa0Simon Wells\xa0has been appointed Executive Production Editor, reporting to David Crow. Simon’s appointment will continue our efforts to strengthen the hub in New York. Simon comes to us from The Times and The Sunday Times in London, where he was [&#8230;]'),
#  ('url',
#   'https://talkingbiznews.com/media-news/wsj-hires-wells-as-executive-production-editor/'),
#  ('source', 'Talking Biz News'),
#  ('image', None),
#  ('category', 'business'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:14:39+00:00'),
#  ('author', 'Taylor Ekbatani'),
#  ('title', 'Gallery: STN EXPO East Trade Show/Networking Madness Reception'),
#  ('description',
#   'CONCORD, N.C. — STN EXPO East in North Carolina wrapped up with a Trade Show featuring vendors from technology companies to OEMs to alternative transportation providers and more. The night ended with a reception featuring food and drinks with a theme fitting for the postseason college basketball tournaments. Vendors and attendees were encouraged to show [&#8230;]The post Gallery: STN EXPO East Trade Show/Networking Madness Reception appeared first on School Transportation News.'),
#  ('url',
#   'https://stnonline.com/event-news/gallery-stn-expo-east-trade-show-networking-madness-reception/'),
#  ('source', 'stnonline'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:14:20+00:00'),
#  ('author', 'Phillip Powell'),
#  ('title',
#   'Wind power, waterfowl and crypto: The energy and environment bills to watch at the state Capitol'),
#  ('description',
#   'Struggling to keep up with environmental policy changes from the State Legislature? Read on, we&#8217;ve got you covered.'),
#  ('url',
#   'https://arktimes.com/arkansas-blog/2025/03/27/wind-power-waterfowl-and-crypto-the-energy-and-environment-bills-to-watch-at-the-state-capitol'),
#  ('source', 'arktimes'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:14:14+00:00'),
#  ('author', 'Steve DelVecchio'),
#  ('title', 'Adam Schefter shares big update on Aaron Rodgers situation'),
#  ('description',
#   'The Pittsburgh Steelers met with Aaron Rodgers in person last week, which led many to believe that the two sides were closing in on a contract agreement. There is still no deal in place, however, and it does not sound like the Steelers have any idea when or if that might change. Rodgers visited with &#8230;The post Adam Schefter shares big update on Aaron Rodgers situation appeared first on Larry Brown Sports.'),
#  ('url',
#   'https://larrybrownsports.com/football/adam-schefter-aaron-rodgers-steelers-dark/688917'),
#  ('source', 'larrybrownsports'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:14:11+00:00'),
#  ('author', 'Peter Burditt'),
#  ('title',
#   'How Ronnie Wood Saved Bob Dylan’s Live Aid Performance From Near Disaster in 1985'),
#  ('description',
#   "Back in 1985, a snapped string almost put a damper on Bob Dylan's Live Aid performance; luckily, Ronnie Wood was there to save the day.The post How Ronnie Wood Saved Bob Dylan’s Live Aid Performance From Near Disaster in 1985 appeared first on American Songwriter."),
#  ('url',
#   'https://americansongwriter.com/how-ronnie-wood-saved-bob-dylans-live-aid-performance-in-1985/'),
#  ('source', 'americansongwriter'),
#  ('image', 'https://www.youtube.com/embed/u0Lx3supRTQ'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:14:07+00:00'),
#  ('author', 'Ed Gruver'),
#  ('title',
#   'Hershey Medical Center first in Pa. to offer new Parkinson’s Disease treatment'),
#  ('description',
#   "Penn State Health Milton S. Hershey Medical Center is Pennsylvania's first hospital to offer BrainSense adaptive deep brain stimulation for Parkinson’s Disease.The post Hershey Medical Center first in Pa. to offer new Parkinson&#8217;s Disease treatment appeared first on Central Penn Business Journal."),
#  ('url',
#   'https://www.cpbj.com/hershey-medical-center-first-in-pa-to-offer-new-parkinsons-disease-treatment/'),
#  ('source', 'centralpennbusiness'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:14:04+00:00'),
#  ('author', 'Thomas Barrabi'),
#  ('title',
#   'Why Elon Musk’s Tesla has an advantage as Trump’s 25% auto tariffs hit'),
#  ('description',
#   'Elon Musk’s Tesla could have an advantage on key rivals in the auto sector after President Trump imposed harsh 25% tariffs on all foreign-made cars and auto parts like engines and transmissions.'),
#  ('url',
#   'https://nypost.com/2025/03/27/business/elon-musks-tesla-has-an-advantage-as-trumps-25-auto-tariffs-hit/'),
#  ('source', 'Post'),
#  ('image',
#   'https://nypost.com/wp-content%2Fuploads%2Fsites%2F2%2F2025%2F03%2Flogo-tesla-pictured-tesla-super-101192476.jpg?quality%3D90%26strip%3Dall'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'zm'),
#  ('published_at', '2025-03-27T16:14:03+00:00'),
#  ('author', None),
#  ('title', 'Karo ekspertai: rusai slapčia atsigabeno itin galingą techniką'),
#  ('description',
#   'Pilietinio gynybos ir saugumo analizės centro „Locked N’ Loaded“ ekspertai teigia, kad agresoriaus karo propagandistai dalinasi nuotrauka, kurioje matosi geležinkelio ešelonas bei šiaurės korėjiečių haubica „Koksan“ ir MLRS M1991 užtaisymo technika.'),
#  ('url',
#   'https://www.delfi.lt/news/daily/lithuania/karo-ekspertai-rusai-slapcia-atsigabeno-itin-galinga-technika-120096888'),
#  ('source', 'DELFI'),
#  ('image',
#   'https://images.delfi.lt/media-api-image-cropper/v1/1665bce3-189f-4aa9-a3d5-a5a24894930a.jpg?noup&w=120&h=120&fx=0.5&fy=0.5'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'lt'),
#  ('published_at', '2025-03-27T16:13:54+00:00'),
#  ('author', 'Maša Momirović'),
#  ('title',
#   'Proteinski prah od graška vs. vej proteini: Dosta sličnosti, ali jedna razlika je ključna'),
#  ('description',
#   'Istražujemo sličnosti i razlike proteinskih preparata od surutke i proteina graška. Koje su sličnosti, koje razlike i da li nekom od treba dati prednost?'),
#  ('url',
#   'https://plantbased.telegraf.rs/pb-kuhinja/pb-saveti/4079873-proteinski-prah-od-graska-vs-vej-proteini-dosta-slicnosti-ali-jedna-razlika-je-kljucna'),
#  ('source', 'Telegraf'),
#  ('image', 'https://xdn.tf.rs/2025/03/27/shutterstock2176679585.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'rs'),
#  ('published_at', '2025-03-27T16:13:43+00:00'),
#  ('author', 'Reda Wigle'),
#  ('title',
#   'Your heavy period could be a sign of this blood disorder — it’s under-diagnosed in women'),
#  ('description',
#   "Sherri Ozawa, MSN, RN, told The Post that serious blood loss during menstruation could be a symptom of a blood disorder that compromises the body's ability to form blood clots."),
#  ('url',
#   'https://nypost.com/2025/03/27/health/your-heavy-period-could-be-a-sign-of-this-blood-disorder/'),
#  ('source', 'Post'),
#  ('image',
#   'https://nypost.com/wp-content%2Fuploads%2Fsites%2F2%2F2025%2F03%2Fyoung-woman-lying-bed-menstrual-101194015.jpg?quality%3D90%26strip%3Dall'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'zm'),
#  ('published_at', '2025-03-27T16:13:42+00:00'),
#  ('author', 'Naharnet Newsdesk'),
#  ('title',
#   "Raad calls for ending occupation through 'diplomacy or resistance or both'"),
#  ('description',
#   "Raad calls for ending occupation through 'diplomacy or resistance or both'"),
#  ('url',
#   'https://naharnet.com/stories/en/311882-raad-calls-for-ending-occupation-through-diplomacy-or-resistance-or-both'),
#  ('source', 'naharnet'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:13:40+00:00'),
#  ('author', 'mirrornews@mirror.co.uk (Graham Hiscott)'),
#  ('title',
#   "Rachel Reeves' Spring Statement: Experts react to controversial changes – 'she'll need more'"),
#  ('description',
#   "The spring statement, worsening economy and Donald Trump's latest trade tariffs on cars has led to renewed speculation about more tax rises to come and a further hit to hard-up households"),
#  ('url',
#   'https://www.mirror.co.uk/news/politics/rachel-reeves-spring-statement-experts-34945428'),
#  ('source', 'Mirror'),
#  ('image',
#   'https://i2-prod.mirror.co.uk/incoming/article34942513.ece/ALTERNATES/s98/3_Chancellor-Rachel-Reeves-Holds-Press-Conference-On-The-Spring-Statement.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'gb'),
#  ('published_at', '2025-03-27T16:13:27+00:00'),
#  ('author', 'AP News'),
#  ('title',
#   'Musk announces $1 million for Wisconsin voter in Supreme Court race. Opposition calls it ‘corrupt’'),
#  ('description',
#   'MADISON, Wis. (AP) — Billionaire Elon Musk says a Wisconsin voter has been awarded $1 million days before the conclusion of a fiercely contested state Supreme Court election that has broken spending records and become a referendum on Musk and the first months of President Donald Trump&#8217;s administration. The payment to a Green Bay man, [&#8230;]'),
#  ('url',
#   'https://www.mymotherlode.com/news/national/general-election/3693330/musk-announces-1-million-for-wisconsin-voter-in-supreme-court-race-opposition-calls-it-corrupt.html'),
#  ('source', 'mymotherlode'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:13:26+00:00'),
#  ('author', 'Contributing Writer'),
#  ('title', 'Can the historic North Hollywood Arts District make a comeback?'),
#  ('description',
#   'NoHo once boasted the second-largest theater district in the country, with 22 live theaters, trailing only Broadway.'),
#  ('url',
#   'https://www.dailynews.com/2025/03/27/can-the-historic-north-hollywood-arts-district-make-a-comeback/'),
#  ('source', 'dailynews'),
#  ('image',
#   'https://www.dailynews.com/wp-content/uploads/2025/03/LDN-L-NOHO-ARTS-01-0316.jpg?w=1400px&strip=all'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:13:23+00:00'),
#  ('author', 'mirrornews@mirror.co.uk (Niamh Kirk)'),
#  ('title',
#   "'My mum was brutally killed - now people use her name as codeword in pubs'"),
#  ('description',
#   'A woman who was brutally killed by her husband of just three months has gone on to save thousands of people in her legacy who may be feeling uncomfortable while on a date'),
#  ('url',
#   'https://www.mirror.co.uk/news/uk-news/my-mum-brutally-killed-now-34943791'),
#  ('source', 'Mirror'),
#  ('image',
#   'https://i2-prod.mirror.co.uk/incoming/article34944238.ece/ALTERNATES/s98/1_Angela-Phillips-murder.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'gb'),
#  ('published_at', '2025-03-27T16:13:14+00:00'),
#  ('author', None),
#  ('title', 'Bosso gear up for Zwigananda FC showdown'),
#  ('description',
#   'Highlanders head coach Kelvin Kaindu is optimistic about having a fully fit squad as his side prepares to host Premier Soccer League debutants Scottland FC at Barbourfields Stadium on Sunday.T...'),
#  ('url', 'http://bulawayo24.com/news/local/251546'),
#  ('source', 'Bulawayo24 News'),
#  ('image',
#   'http://img.bulawayo24.com/articles/thumbs/65x52/Highlanders-2_Bosso.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'zw'),
#  ('published_at', '2025-03-27T16:13:08+00:00'),
#  ('author', 'Andrija Ivanović'),
#  ('title',
#   'Zbog ove mape Evrope Srbija može biti ponosna, ali za neke zemlje napravljena je velika greška'),
#  ('description',
#   '„U koliko svetskih ratova je vaša zemlja pobedila?“ Ovo pitanje pojavljuje se iznad mape Evrope objavljene na TikToku, na nalogu korisnika @bosnian_mapper20, a.'),
#  ('url',
#   'https://nauka.telegraf.rs/arheo-istorija/4079950-zbog-ove-mape-evrope-srbija-moze-biti-ponosna-ali-za-neke-zemlje-napravljena-je-velika-greska'),
#  ('source', 'Telegraf'),
#  ('image', 'https://xdn.tf.rs/2025/03/27/mapa-rat-.jpg?ver=530497'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'rs'),
#  ('published_at', '2025-03-27T16:13:06+00:00'),
#  ('author', 'Naharnet Newsdesk'),
#  ('title', 'Jumblat accuses Israel of exploiting Druze minority in Syria'),
#  ('description',
#   'Jumblat accuses Israel of exploiting Druze minority in Syria'),
#  ('url',
#   'https://naharnet.com/stories/en/311894-jumblat-accuses-israel-of-exploiting-druze-minority-in-syria'),
#  ('source', 'naharnet'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:12:51+00:00'),
#  ('author', 'AP News'),
#  ('title',
#   'Lebanon appoints new central bank governor as it works to climb out of economic crisis'),
#  ('description',
#   'BEIRUT (AP) — Lebanon appointed asset manager Karim Souaid to the post of central bank governor Thursday as the government tries to reform the economy after months of war and decades of mismanagement and corruption. The country&#8217;s economy has been in crisis for five years and desperately needs reforms to unlock international aid, and on [&#8230;]'),
#  ('url',
#   'https://www.mymotherlode.com/news/middle-east/3693316/lebanon-appoints-new-central-bank-governor-as-it-works-to-climb-out-of-economic-crisis.html'),
#  ('source', 'mymotherlode'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:12:49+00:00'),
#  ('author', 'Aisha Malik'),
#  ('title', 'TikTok to launch TikTok Shop in France, Germany, and Italy'),
#  ('description',
#   'TikTok is set to expand its TikTok Shop e-commerce platform to users in France, Germany, and Italy on Monday, Reuters reports. TikTok Shop has been available in the United Kingdom since 2021, and now the company is ready to expand further into Europe. While TikTok Shop is also available in the United States and saw [&#8230;]'),
#  ('url',
#   'https://techcrunch.com/2025/03/27/tiktok-to-launch-tiktok-shop-in-france-germany-and-italy/'),
#  ('source', 'TechCrunch'),
#  ('image', None),
#  ('category', 'technology'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:12:40+00:00'),
#  ('author', 'Ahad Sanwari'),
#  ('title', "Billie Eilish's photos in lacy lingerie spark fan frenzy"),
#  ('description',
#   'Billie Eilish sparked fan reaction with a new set of photos with her lacy outfits, read more…'),
#  ('url',
#   'https://www.hellomagazine.com/fashion/celebrity-style/822829/billie-eilish-lacy-lingerie-photos-fans-react/'),
#  ('source', 'hellomagazine'),
#  ('image',
#   'https://images.hellomagazine.com/horizon/landscape/49213a96cb2e-billie-eilish-fire-relief.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:12:40+00:00'),
#  ('author', 'Dominic Cotroneo'),
#  ('title', 'Brewers release 2025 Opening Day Roster'),
#  ('description',
#   'The Milwaukee Brewers aim to three-peat as National League Central Division champions as they begin their season Thursday. 2025 is reigning NL Manager of the Year Pat Murphy&#8217;s second season at the helm of the club. Here is the roster will open with in The Bronx to face the New York Yankees. All players are [&#8230;]The post Brewers release 2025 Opening Day Roster appeared first on WTMJ.'),
#  ('url',
#   'https://wtmj.com/sports/2025/03/27/brewers-release-2025-opening-day-roster/'),
#  ('source', '620wtmj'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:12:37+00:00'),
#  ('author', 'Danni Scott'),
#  ('title',
#   'Sam Fender seen with ‘secret’ girlfriend for first time at star-studded Sir Elton John gig'),
#  ('description', "They've been together for two years."),
#  ('url',
#   'https://metro.co.uk/2025/03/27/sam-fender-seen-secret-girlfriend-first-time-star-studded-sir-elton-john-gig-22804680/'),
#  ('source', 'Metro'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'gb'),
#  ('published_at', '2025-03-27T16:12:22+00:00'),
#  ('author', 'By The Newsroom'),
#  ('title',
#   'Dog-friendly, foodie delights and stunning scenery – the Isle of Wight is a perfect springtime destination'),
#  ('description',
#   'Is there a more enchanting place than the Isle of Wight at this time of year? It’s a pocket of tranquillity just waiting to be discovered this springtime.'),
#  ('url',
#   'https://www.portsmouth.co.uk/sponsored/is-there-a-more-enchanting-place-than-the-isle-of-wight-at-this-time-of-year-its-a-pocket-of-tranquillity-5055306'),
#  ('source', 'haylingtoday'),
#  ('image',
#   'https://www.portsmouth.co.uk/jpim-static/image/2025/03/27/16/37/INTRO_pic.jpeg?width=1200&auto=webp&crop=3%3A2'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'uk'),
#  ('published_at', '2025-03-27T16:12:19+00:00'),
#  ('author', None),
#  ('title',
#   'North Sea oil firm to hand investors a maiden dividend as it returns to profit'),
#  ('description',
#   'After two consecutive annual losses, EnQuest rebounded to a $93.8million profit in 2024 even though its revenue slumped by approximately a fifth to $1.2billion.'),
#  ('url',
#   'https://www.dailymail.co.uk/money/markets/article-14543193/North-Sea-oil-firm-hand-investors-maiden-dividend-returns-profit.html?ns_mchannel=rss&ns_campaign=1490&ito=1490'),
#  ('source', 'thisismoney'),
#  ('image',
#   'https://i.dailymail.co.uk/1s/2025/03/27/15/96634087-0-image-m-38_1743089585758.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'uk'),
#  ('published_at', '2025-03-27T16:12:17+00:00'),
#  ('author', 'Jamie Young'),
#  ('title',
#   'Trump’s car tariffs wipe billions off European automakers as global trade war escalates'),
#  ('description',
#   'Trump’s 25% tariffs on imported cars and parts hit European and UK carmakers hard, wiping billions off valuations and threatening exports. Experts warn of a major blow to global trade and UK GDP.Read more: Trump’s car tariffs wipe billions off European automakers as global trade war escalates'),
#  ('url',
#   'https://bmmagazine.co.uk/news/trumps-car-tariffs-wipe-billions-off-european-automakers-as-global-trade-war-escalates/'),
#  ('source', "Business Matters | The Uk's Leading Sme Business Magazine"),
#  ('image', None),
#  ('category', 'business'),
#  ('language', 'en'),
#  ('country', 'gb'),
#  ('published_at', '2025-03-27T16:11:57+00:00'),
#  ('author', 'Jared Serbu'),
#  ('title',
#   'Protected: DoD Modernization Exchange 2025: Palo Alto Networks’ Jim Smid on agentic AI for cyber defense'),
#  ('description',
#   'There is no excerpt because this is a protected post.The post Protected: DoD Modernization Exchange 2025: Palo Alto Networks’ Jim Smid on agentic AI for cyber defense first appeared on Federal News Network.'),
#  ('url',
#   'https://federalnewsnetwork.com/federal-insights/2025/03/dod-modernization-exchange-2025-palo-alto-networks-jim-smid-on-agentic-ai-for-cyber-defense/'),
#  ('source', 'federalnewsradio'),
#  ('image',
#   'https://federalnewsnetwork.com/wp-content/uploads/2025/03/DoD-Modernization-Exchange-2025-1024x576.png'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:54+00:00'),
#  ('author', 'Lily Radziemski'),
#  ('title',
#   'French extreme-right leader Jordan Bardella distances party from antisemitic roots on Israel visit'),
#  ('description',
#   "For the first time, a member of the National Rally was formally invited to Israel. It's a victory in the party's mission to rebrand itself as critics warn of an Islamophobic undercurrent."),
#  ('url',
#   'https://www.courthousenews.com/french-extreme-right-leader-jordan-bardella-distances-party-from-antisemitic-roots-on-israel-visit/'),
#  ('source', 'courthousenews'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:53+00:00'),
#  ('author', None),
#  ('title', '5 Reasons Shell Is On The Up And Up (Rating Upgrade)'),
#  ('description', '5 Reasons Shell Is On The Up And Up (Rating Upgrade)'),
#  ('url',
#   'https://seekingalpha.com/article/4770907-5-reasons-shell-up-rating-upgrade?source=feed_all_articles'),
#  ('source', 'Seeking Alpha'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:52+00:00'),
#  ('author', 'odalys'),
#  ('title', 'Recorre Díaz-Canel municipios de Guantánamo'),
#  ('description',
#   'Imagen principal:&nbsp; Díaz Canel recorre sitios de interés económico y social de Guantánamo. Foto: Redes sociales del Presidente cubano\xa0El presidente de Cuba, Miguel Díaz-Canel, realiza hoy una visita a la provincia de Guantánamo, con el propósito de analizar el trabajo en el territorio e intercambiar con los pobladores.«Siempre es grato regresar a Guantánamo, tierra de un pueblo noble, patriota y trabajador», manifestó el propio jefe de Estado en X.«Asimismo, comentó que «este jueves» concluye «en la más oriental provincia de Cuba, el primer ciclo de recorridos por sus diez...'),
#  ('url', 'http://cubasi.cu/en/node/405428'),
#  ('source', 'CubaSi.cu'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'cu'),
#  ('published_at', '2025-03-27T16:11:52+00:00'),
#  ('author', None),
#  ('title',
#   'WATCH: Secret Service intercept child who slipped through White House fence'),
#  ('description',
#   'The child was returned to their parents without incident, the agency said.'),
#  ('url',
#   'https://abcnews.go.com/US/video/secret-service-intercept-child-slipped-white-house-fence-120209871'),
#  ('source', 'ABC News'),
#  ('image',
#   'https://s.abcnews.com/images/US/250327_abc_soc_secret_service2_hpMain_4x3_384.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:47+00:00'),
#  ('author', 'The Options Insider'),
#  ('title',
#   'Most Active Equity Options For Mid-Day, March 27, 2025 – TSLA, NVDA, GME, AMD, PLTR, AMZN, AAPL, PFE, AVGO, RIVN, NIO, META, MSTR, HOOD, INTC, BABA, F, SMCI, NKE, SOFI'),
#  ('description', 'Data Courtesy Of Trade Alert\xa0\xa0'),
#  ('url',
#   'https://theoptionsinsider.com/news/most-active-options/most-active-equity-options-for-mid-day-march-27-2025-tsla-nvda-gme-amd-pltr-amzn-aapl-pfe-avgo-rivn-nio-meta-mstr-hood-intc-baba-f-smci-nke-sofi/'),
#  ('source', 'theoptionsinsider'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:35+00:00'),
#  ('author', 'Petty Officer 1st Class Hannah Fry'),
#  ('title',
#   'USS Ralph Johnson Sails Through the Strait of Malacca [Image 8 of 8]'),
#  ('description',
#   'STRAIT OF MALACCA (March 25, 2025) Cmdr. Justan Caesar, the commanding officer of the Arleigh Burke-class guided-missile destroyer USS Ralph Johnson (DDG 114), stands on the bridge-wing while transiting through the Strait of Malacca, March 25. Ralph Johnson is forward deployed and assigned to Destroyer Squadron (DESRON) 15, the Navy’s largest DESRON and the U.S. 7th fleet’s principal surface force. (U.S. Navy photo by Mass Communication Specialist 1st Class Hannah Fry)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938956/uss-ralph-johnson-sails-through-strait-malacca'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938956/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:31+00:00'),
#  ('author', 'Petty Officer 1st Class Hannah Fry'),
#  ('title', 'HSM 49 det. 4 Flies in the Andaman Sea [Image 7 of 8]'),
#  ('description',
#   'ANDAMAN SEA (March 26, 2025) Damage Controlman Fireman Christian Mendoza from Killeen, Texas, watches as an MH-60R assigned to Helicopter Maritime Strike Squadron (HSM) 49 det. 4 the “High Rollers” as it sits on the flight deck of the Arleigh Burke-class guided-missile destroyer USS Ralph Johnson (DDG 114) during flight operations in the Andaman Sea, March 26. Ralph Johnson is forward deployed and assigned to Destroyer Squadron (DESRON) 15, the Navy’s largest DESRON and the U.S. 7th fleet’s principal surface force. (U.S. Navy photo by Mass Communication Specialist 1st Class Hannah Fry)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938945/hsm-49-det-4-flies-andaman-sea'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938945/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:31+00:00'),
#  ('author', 'Petty Officer 1st Class Hannah Fry'),
#  ('title',
#   'USS Ralph Johnson Sails Through the Strait of Malacca [Image 6 of 8]'),
#  ('description',
#   'STRAIT OF MALACCA (March 25, 2025) Quartermaster Seaman Randy Rivera Rodriguez from San Juan, Puerto Rico, stands on the bridge-wing of the Arleigh Burke-class guided-missile destroyer USS Ralph Johnson (DDG 114) while transiting through the Strait of Malacca, March 25. Ralph Johnson is forward deployed and assigned to Destroyer Squadron (DESRON) 15, the Navy’s largest DESRON and the U.S. 7th fleet’s principal surface force. (U.S. Navy photo by Mass Communication Specialist 1st Class Hannah Fry)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938943/uss-ralph-johnson-sails-through-strait-malacca'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938943/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:31+00:00'),
#  ('author', 'Petty Officer 1st Class Hannah Fry'),
#  ('title',
#   'USS Ralph Johnson Sails Through the Strait of Malacca [Image 5 of 8]'),
#  ('description',
#   'STRAIT OF MALACCA (March 25, 2025) Yeoman 2nd Class Jeremy Bistline from Colorado City, Arizona, stands on the bridge-wing of the Arleigh Burke-class guided-missile destroyer USS Ralph Johnson (DDG 114) while transiting through the Strait of Malacca, March 25. Ralph Johnson is forward deployed and assigned to Destroyer Squadron (DESRON) 15, the Navy’s largest DESRON and the U.S. 7th fleet’s principal surface force. (U.S. Navy photo by Mass Communication Specialist 1st Class Hannah Fry)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938924/uss-ralph-johnson-sails-through-strait-malacca'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938924/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:31+00:00'),
#  ('author', 'Petty Officer 1st Class Hannah Fry'),
#  ('title', 'HSM 49 det. 4 Flies in the Andaman Sea [Image 3 of 8]'),
#  ('description',
#   'ANDAMAN SEA (March 26, 2025) An MH-60R assigned to Helicopter Maritime Strike Squadron (HSM) 49 det. 4 the “High Rollers” sits on the flight deck of the Arleigh Burke-class guided-missile destroyer USS Ralph Johnson (DDG 114) during flight operations in the Andaman Sea, March 26. Ralph Johnson is forward deployed and assigned to Destroyer Squadron (DESRON) 15, the Navy’s largest DESRON and the U.S. 7th fleet’s principal surface force. (U.S. Navy photo by Mass Communication Specialist 1st Class Hannah Fry)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938891/hsm-49-det-4-flies-andaman-sea'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938891/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:30+00:00'),
#  ('author', 'Petty Officer 1st Class Hannah Fry'),
#  ('title', 'HSM 49 det. 4 Flies in the Andaman Sea [Image 2 of 8]'),
#  ('description',
#   'ANDAMAN SEA (March 26, 2025) Seaman Christopher Alexandre from Freeport, New York, right, and Boatswain’s Mate 1st Class Mele Filiai from Lahaina, Maui, Hawaii, left, remove the chocks and chains from an MH-60R assigned to Helicopter Maritime Strike Squadron (HSM) 49 det. 4 the “High Rollers” as it prepares to take off from the flight deck of the Arleigh Burke-class guided-missile destroyer USS Ralph Johnson (DDG 114) during flight operations in the Andaman Sea, March 26. Ralph Johnson is forward deployed and assigned to Destroyer Squadron (DESRON) 15, the Navy’s largest DESRON and the...'),
#  ('url',
#   'https://www.dvidshub.net/image/8938888/hsm-49-det-4-flies-andaman-sea'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938888/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:30+00:00'),
#  ('author', 'Petty Officer 1st Class Hannah Fry'),
#  ('title', 'HSM 49 det. 4 Flies in the Andaman Sea [Image 1 of 8]'),
#  ('description',
#   'ANDAMAN SEA (March 26, 2025) Aviation Electronics Technician Airman Branden Calvey from Scranton, Virginia, left, walks around an MH-60R assigned to Helicopter Maritime Strike Squadron (HSM) 49 det. 4 the “High Rollers” as it sits on the flight deck of the Arleigh Burke-class guided-missile destroyer USS Ralph Johnson (DDG 114) during flight operations in the Andaman Sea, March 26. Ralph Johnson is forward deployed and assigned to Destroyer Squadron (DESRON) 15, the Navy’s largest DESRON and the U.S. 7th fleet’s principal surface force. (U.S. Navy photo by Mass Communication Specialist...'),
#  ('url',
#   'https://www.dvidshub.net/image/8938885/hsm-49-det-4-flies-andaman-sea'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938885/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:30+00:00'),
#  ('author', 'Petty Officer 1st Class Hannah Fry'),
#  ('title',
#   'USS Ralph Johnson Sails Through the Strait of Malacca [Image 4 of 8]'),
#  ('description',
#   'STRAIT OF MALACCA (March 25, 2025) Ensign Isaac Gomez from Staten Island, New York, scans the horizon using binoculars from the pilot house of the Arleigh Burke-class guided-missile destroyer USS Ralph Johnson (DDG 114) while transiting through the Strait of Malacca, March 25. Ralph Johnson is forward deployed and assigned to Destroyer Squadron (DESRON) 15, the Navy’s largest DESRON and the U.S. 7th fleet’s principal surface force. (U.S. Navy photo by Mass Communication Specialist 1st Class Hannah Fry)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938916/uss-ralph-johnson-sails-through-strait-malacca'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938916/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:30+00:00'),
#  ('author', None),
#  ('title', "UEFA'dan Real Madrid'in yıldız futbolcuları için soruşturma"),
#  ('description',
#   "Real Madrid ile Atletico Madrid arasında oynanan karşılaşmada yaşananlara ilişkin soruşturma başladı.UEFA'dan yapılan a..."),
#  ('url',
#   'https://www.yenisafak.com/spor/uefadan-real-madridin-yildiz-futbolculari-icin-sorusturma-4689183'),
#  ('source', 'Yeni Safak'),
#  ('image',
#   "https://img.piri.net/mnresize/500/-/piri/upload/3/2025/3/27/ea6f3cdc-aj88tsa0dmu4eohtys7id.jpeg UEFA'dan Real Madrid'in yıldız futbolcuları için soruşturma https://www.yenisafak.com/spor/uefadan-real-madridin-yildiz-futbolculari-icin-sorusturma-4689183"),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'tr'),
#  ('published_at', '2025-03-27T16:11:24+00:00'),
#  ('author', None),
#  ('title',
#   'The 35+ best anti-Amazon Spring Sale deals 2025: Walmart, Best Buy, Costco, and more'),
#  ('description',
#   "Amazon's Big Spring Sale is here through March 31, but you can shop seasonal savings at other retailers like Walmart, Best Buy, and more."),
#  ('url',
#   'https://www.zdnet.com/article/best-anti-amazon-spring-sale-deals-3-27-2025/'),
#  ('source', 'zdnet'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:19+00:00'),
#  ('author', 'Marta Petrović'),
#  ('title',
#   'Verila se "seksualno najaktivnija žena" sa novim ciljem: Spavaće sa njih 1.000, on ne sme NI DA POGLEDA DRUGU'),
#  ('description',
#   'Zvezda Onlifansa koja je nazvana "seksualno najaktivnija žena u Australiji" kaže da je njena veridba neće sprečiti.'),
#  ('url',
#   'https://ona.telegraf.rs/lifestyle/ljubav/4079955-verila-se-seksualno-najaktivnija-zena-sa-novim-ciljem-spavace-sa-njih-1000-on-ne-sme-ni-da-pogleda-drugu'),
#  ('source', 'Telegraf'),
#  ('image', 'https://xdn.tf.rs/2024/09/21/1726922013561-annie-knight2.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'rs'),
#  ('published_at', '2025-03-27T16:11:18+00:00'),
#  ('author', 'Shane Shoemaker'),
#  ('title',
#   'Colorado’s Shedeur Sanders gets bust comparison to former Steelers first-round pick'),
#  ('description',
#   'While many see Shedeur Sanders as a top pick, one draft expert is warning what could happen if his NFL career goes off track.'),
#  ('url',
#   'https://www.sportingnews.com/us/ncaa-football/news/colorados-shedeur-sanders-gets-bust-comparison-former-steelers-first-round-pick-kenny-pickett/7e98bf0623bd29bc9cd61737'),
#  ('source', 'Sporting News'),
#  ('image',
#   'https://library.sportingnews.com/styles/crop_style_16_9_desktop_webp/s3/2024-11/USATSI_24721545.jpg.webp?itok=GP07-yKS'),
#  ('category', 'sports'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:15+00:00'),
#  ('author', 'Akshara R'),
#  ('title',
#   '“Almost Had Me”: Kyle Busch Heaps Praises on 9 YO Son as Brexton Gets Schooled in Rubbing Tires'),
#  ('description',
#   '&#8220;I had him!&#8221;\xa0recalled Dale Jr. Having grown up watching the Intimidator duke it out on the track, it was only time before Junior would want to beat his father at his own game. The thrilling 1999 IROC race in Michigan, where Dale Sr. just managed to beat his son at the finish line, is forever [&#8230;]The post “Almost Had Me”: Kyle Busch Heaps Praises on 9 YO Son as Brexton Gets Schooled in Rubbing Tires appeared first on EssentiallySports.'),
#  ('url',
#   'https://www.essentiallysports.com/nascar-news-almost-had-me-kyle-busch-heaps-praises-on-nine-yo-son-as-brexton-gets-schooled-in-rubbing-tires/'),
#  ('source', 'Essentially Sports'),
#  ('image',
#   'https://video.essentiallysports.com/videos/NASCAR/60ad882f-a8ca-49b3-8559-7484facb270c.mp4'),
#  ('category', 'sports'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:14+00:00'),
#  ('author', 'reporters@dailyrecord.co.uk (Elina Kobzar)'),
#  ('title', 'Kilmarnock man donates kidney to his mother-in-law'),
#  ('description',
#   'Richard Charlwood and his mother-in-law Anne Binning are both in recovery after a kidney transplant operation.'),
#  ('url',
#   'https://www.dailyrecord.co.uk/ayrshire/kilmarnock-man-donates-kidney-mother-34934443'),
#  ('source', 'Daily Record'),
#  ('image',
#   'https://i2-prod.dailyrecord.co.uk/incoming/article34935227.ece/ALTERNATES/s98/0_AMP_SDR_250325_DONOR_00018_copy.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'gb'),
#  ('published_at', '2025-03-27T16:11:14+00:00'),
#  ('author', 'Canadian Press'),
#  ('title',
#   '‘It’s the Wild West’: How AI is creating new frontiers for crime in Canada'),
#  ('description',
#   'By Brieanna Charlebois VANCOUVER &#8212; There&#8217;s deepfake pornography. Voice impersonation. Romance scams that turn into financial fraud. Canadian police patrolling corners of the dark web are well aware of the commonly nefarious ways criminals exploit artificial intelligence. But recently there&#8217;s been a new twist &#8212; criminals offering to &#8220;jailbreak&#8221; the very algorithms that form the [&#8230;]'),
#  ('url',
#   'https://winnipegsun.com/pmn/its-the-wild-west-how-ai-is-creating-new-frontiers-for-crime-in-canada-2'),
#  ('source', 'altonaecho'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:14+00:00'),
#  ('author', None),
#  ('title',
#   'New Benchmarks Challenge Brute Force Approach to AI - BankInfoSecurity.com'),
#  ('description',
#   'New Benchmarks Challenge Brute Force Approach to AI&nbsp;&nbsp;BankInfoSecurity.comWill A.I. Soon Outsmart Humans? Play This Puzzle to Find Out.&nbsp;&nbsp;The New York TimesLLMs Hit a New Low on ARC-AGI-2 Benchmark, Pure LLMs Score 0%&nbsp;&nbsp;AIMA new, challenging AGI test stumps most AI models&nbsp;&nbsp;TechCrunchARC Prize launches its toughest AI benchmark yet: ARC-AGI-2&nbsp;&nbsp;AI News'),
#  ('url',
#   'https://news.google.com/rss/articles/CBMilwFBVV95cUxQNHluWE52N2xQOFV1QTE5LXhYakkwNzNmT3F5STlNSlFkWW9DM3R6empxdEhEUlNGTElsWnFwclp4MGNYbXZJN1pXelZpamVwbzA2Z2p5QWFrQkozbW05REpJdU9NMmN1aVdzYXJJRmJRZ2stX2pYWG55b1FBZndfeGVEa3l6NnV2ZDBtNk56ODhoSTFVbUNr?oc=5'),
#  ('source', 'Google News Technology IN'),
#  ('image', None),
#  ('category', 'technology'),
#  ('language', 'en'),
#  ('country', 'in'),
#  ('published_at', '2025-03-27T16:11:13+00:00'),
#  ('author', 'Arthur Zaczkiewicz'),
#  ('title',
#   'Unlocking Gen Z’s Potential: How Brands Can Thrive With the Most Influential\xa0Generation'),
#  ('description',
#   "Insights from Ogilvy and Emarketer reveal Gen Z's shopping preferences, economic power and strategies for building brand loyalty."),
#  ('url',
#   'https://wwd.com/business-news/business-features/unlocking-gen-zs-potential-how-brands-1237064023/'),
#  ('source', 'wwd'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:12+00:00'),
#  ('author', 'Kyle Barr'),
#  ('title',
#   'Nintendo’s ‘Virtual Game Cards’ Show How You Might Port Your Switch Library to Switch 2'),
#  ('description',
#   'Plus, Nintendo has a new app where you can nab all the news for Switch 2 right when it happens.'),
#  ('url',
#   'https://gizmodo.com/nintendos-virtual-game-cards-show-how-you-might-port-your-switch-library-to-switch-2-2000581584'),
#  ('source', 'gizmodo'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:11:05+00:00'),
#  ('author', 'Web Desk Staff'),
#  ('title', 'Gold rate in Pakistan today, 27 March, 2025'),
#  ('description',
#   'KARACHI—Gold prices in Pakistan remained unchanged on Thursday, March 27, 2025, at PKR 321,300 for 24-karat gold. Moreover, the rate…'),
#  ('url', 'https://pakobserver.net/gold-rate-in-pakistan-today-27-march-2025/'),
#  ('source', 'pakobserver'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:10:59+00:00'),
#  ('author', None),
#  ('title',
#   'People say they prefer stories written by humans over AI, study says otherwise'),
#  ('description', 'Comments'),
#  ('url',
#   'https://theconversation.com/people-say-they-prefer-stories-written-by-humans-over-ai-generated-works-yet-new-study-suggests-thats-not-quite-true-251347'),
#  ('source', 'Hacker News'),
#  ('image', None),
#  ('category', 'technology'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:10:48+00:00'),
#  ('author', 'Doug Goldstein, CFP®'),
#  ('title',
#   'DG’s Profile Perspectives: Steps to a Fulfilling and Worry-Free Retirement'),
#  ('description',
#   '“The question isn’t at what age I want to retire, it’s at what income.”'),
#  ('url',
#   'https://www.jewishpress.com/blogs/doug-goldstein-profile-perspectives/dgs-profile-perspectives-steps-to-a-fulfilling-and-worry-free-retirement/2025/03/27/'),
#  ('source', 'jewishpress'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:10:44+00:00'),
#  ('author', 'Tanmay Kundu'),
#  ('title',
#   'Underestimating Kobe Bryant Backfired Instantly as 2x NBA Champ Made a Brutal “College” Confession to Him'),
#  ('description',
#   '&#8220;Everything negative &#8211; pressure, challenges &#8211; is all an opportunity for me to rise.&#8221; Kobe Bryant didn’t just throw this quote out there. He meant it. Every. Single. Word. 33,643 points. Twenty NBA seasons. Five rings. Eighteen All-Star nods. Indeed, this man was a monster on the court. But this “never to kneel down” mindset [&#8230;]The post Underestimating Kobe Bryant Backfired Instantly as 2x NBA Champ Made a Brutal &#8220;College&#8221; Confession to Him appeared first on EssentiallySports.'),
#  ('url',
#   'https://www.essentiallysports.com/nba-legends-basketball-news-vernon-maxwell-underestimating-kobe-bryant-backfired-instantly-as-two-time-nba-champ-made-a-brutal-college-confession-to-him/'),
#  ('source', 'Essentially Sports'),
#  ('image',
#   'https://video.essentiallysports.com/videos/NBA/d787628b-a175-449b-8938-bf95cdebb75a.mp4'),
#  ('category', 'sports'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:10:40+00:00'),
#  ('author', None),
#  ('title', 'Hundreds of fungi species threatened with extinction: IUCN'),
#  ('description',
#   'Deforestation, farming and climate-fueled fires are driving increasing threats to fungi, the lifeblood of most plants on Earth, the International Union for Conservation of Nature warned Thursday.'),
#  ('url',
#   'https://phys.org/news/2025-03-hundreds-fungi-species-threatened-extinction.html'),
#  ('source', 'physorg'),
#  ('image',
#   'https://scx1.b-cdn.net/csz/news/tmb/2025/fungi-the-lifeblood-of.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:10:36+00:00'),
#  ('author', None),
#  ('title', 'Zanu-PF councillor jailed for contempt of court'),
#  ('description',
#   'Bulawayo Ward One Councillor, Josiah Mutangi, has been sentenced to 30 days in prison after repeatedly defying court orders to vacate a farmhouse at Imbesu Farm, located 25 kilometres outside the city...'),
#  ('url', 'http://bulawayo24.com/news/local/251545'),
#  ('source', 'Bulawayo24 News'),
#  ('image',
#   'http://img.bulawayo24.com/articles/thumbs/65x52/484459641_1133067272190809_7762769178728744948_n-680x380.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'zw'),
#  ('published_at', '2025-03-27T16:10:34+00:00'),
#  ('author', 'mirrornews@mirror.co.uk (Olivia Williams, Tahira Ali)'),
#  ('title',
#   "Prison officer's affair with lag unravelled after police scour burned love letters"),
#  ('description',
#   'Supervisors of prison officer Niamh Lloyd raised concerns about her behaviour whilst she was working in the prison, uncovering a letter which wrote of her sordid affair with an inmate.'),
#  ('url',
#   'https://www.mirror.co.uk/news/uk-news/prison-officers-affair-lag-unravelled-34944093'),
#  ('source', 'Mirror'),
#  ('image',
#   'https://i2-prod.mirror.co.uk/incoming/article34945226.ece/ALTERNATES/s98/1_Niamh-Lloyd.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'gb'),
#  ('published_at', '2025-03-27T16:10:34+00:00'),
#  ('author', 'AP News'),
#  ('title', '5 wounded in stabbing in Amsterdam, 1 person arrested'),
#  ('description',
#   'THE HAGUE, Netherlands (AP) — At least five people have been wounded in a stabbing in Amsterdam, police in the Dutch city said on Thursday. The stabbing happened near Dam Square in central Amsterdam. One person has been arrested. Police have cordoned off the area and multiple ambulances have responded to the event. A trauma [&#8230;]'),
# ...
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:49+00:00'),
#  ('author', 'Spc. Shawn Richardson'),
#  ('title', 'Airborne Integration Course Graduation [Image 9 of 15]'),
#  ('description',
#   'U.S. Army soldiers assigned to the 82nd Airborne Division graduate from the Airborne Integration Course on March 26, 2025, on Fort Bragg, N.C. The Airborne Integration Course welcomes and integrates newly arrived soldiers to the 82nd Airborne Division. (U.S. Army photo by Spc. Shawn Richardson)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938866/airborne-integration-course-graduation'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938866/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:49+00:00'),
#  ('author', 'Spc. Shawn Richardson'),
#  ('title', 'Airborne Integration Course Graduation [Image 8 of 15]'),
#  ('description',
#   'U.S. Army soldiers assigned to the 82nd Airborne Division graduate from the Airborne Integration Course on March 26, 2025, on Fort Bragg, N.C. The Airborne Integration Course welcomes and integrates newly arrived soldiers to the 82nd Airborne Division. (U.S. Army photo by Spc. Shawn Richardson)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938865/airborne-integration-course-graduation'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938865/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:48+00:00'),
#  ('author', 'Spc. Shawn Richardson'),
#  ('title', 'Airborne Integration Course Graduation [Image 3 of 15]'),
#  ('description',
#   'U.S. Army soldiers assigned to the 82nd Airborne Division graduate from the Airborne Integration Course on March 26, 2025, on Fort Bragg, N.C. The Airborne Integration Course welcomes and integrates newly arrived soldiers to the 82nd Airborne Division. (U.S. Army photo by Spc. Shawn Richardson)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938858/airborne-integration-course-graduation'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938858/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:48+00:00'),
#  ('author', 'Spc. Shawn Richardson'),
#  ('title', 'Airborne Integration Course Graduation [Image 7 of 15]'),
#  ('description',
#   'U.S. Army soldiers assigned to the 82nd Airborne Division graduate from the Airborne Integration Course on March 26, 2025, on Fort Bragg, N.C. The Airborne Integration Course welcomes and integrates newly arrived soldiers to the 82nd Airborne Division. (U.S. Army photo by Spc. Shawn Richardson)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938864/airborne-integration-course-graduation'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938864/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:48+00:00'),
#  ('author', 'Spc. Shawn Richardson'),
#  ('title', 'Airborne Integration Course Graduation [Image 6 of 15]'),
#  ('description',
#   'U.S. Army soldiers assigned to the 82nd Airborne Division graduate from the Airborne Integration Course on March 26, 2025, on Fort Bragg, N.C. The Airborne Integration Course welcomes and integrates newly arrived soldiers to the 82nd Airborne Division. (U.S. Army photo by Spc. Shawn Richardson)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938863/airborne-integration-course-graduation'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938863/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:48+00:00'),
#  ('author', 'Spc. Shawn Richardson'),
#  ('title', 'Airborne Integration Course Graduation [Image 4 of 15]'),
#  ('description',
#   'U.S. Army soldiers assigned to the 82nd Airborne Division graduate from the Airborne Integration Course on March 26, 2025, on Fort Bragg, N.C. The Airborne Integration Course welcomes and integrates newly arrived soldiers to the 82nd Airborne Division. (U.S. Army photo by Spc. Shawn Richardson)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938859/airborne-integration-course-graduation'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938859/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:48+00:00'),
#  ('author', 'Spc. Shawn Richardson'),
#  ('title', 'Airborne Integration Course Graduation [Image 5 of 15]'),
#  ('description',
#   'U.S. Army soldiers assigned to the 82nd Airborne Division graduate from the Airborne Integration Course on March 26, 2025, on Fort Bragg, N.C. The Airborne Integration Course welcomes and integrates newly arrived soldiers to the 82nd Airborne Division. (U.S. Army photo by Spc. Shawn Richardson)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938861/airborne-integration-course-graduation'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938861/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:48+00:00'),
#  ('author', 'Spc. Shawn Richardson'),
#  ('title', 'Airborne Integration Course Graduation [Image 2 of 15]'),
#  ('description',
#   'U.S. Army soldiers assigned to the 82nd Airborne Division graduate from the Airborne Integration Course on March 26, 2025, on Fort Bragg, N.C. The Airborne Integration Course welcomes and integrates newly arrived soldiers to the 82nd Airborne Division. (U.S. Army photo by Spc. Shawn Richardson)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938857/airborne-integration-course-graduation'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938857/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:47+00:00'),
#  ('author', 'Spc. Shawn Richardson'),
#  ('title', 'Airborne Integration Course Graduation [Image 1 of 15]'),
#  ('description',
#   'U.S. Army soldiers assigned to the 82nd Airborne Division graduate from the Airborne Integration Course on March 26, 2025, on Fort Bragg, N.C. The Airborne Integration Course welcomes and integrates newly arrived soldiers to the 82nd Airborne Division. (U.S. Army photo by Spc. Shawn Richardson)'),
#  ('url',
#   'https://www.dvidshub.net/image/8938855/airborne-integration-course-graduation'),
#  ('source', 'dvidshub'),
#  ('image',
#   'https://d1ldvf68ux039x.cloudfront.net/thumbs/photos/2503/8938855/250w_q95.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:47+00:00'),
#  ('author', 'staff@jalopnik.com (Brad Brownell)'),
#  ('title',
#   'Six Russian Tourists Killed, 39 Rescued In Red Sea Submarine Crash Off The Coast Of Egypt'),
#  ('description',
#   'An accident in Egypt has once again put submarine tourism safety into the headlines.'),
#  ('url',
#   'https://www.jalopnik.com/1820599/red-sea-submarine-crash-sinks-egypt-coast-russian-tourists/'),
#  ('source', 'jalopnik'),
#  ('image',
#   'https://www.jalopnik.com/img/gallery/six-russian-tourists-killed-39-rescued-in-red-sea-submarine-crash-off-the-coast-of-egypt/l-intro-1743091589.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:37+00:00'),
#  ('author', 'BusinessWorld'),
#  ('title', 'Alternergy to develop wind power project in Albay'),
#  ('description',
#   'RENEWABLE energy developer Alternergy Holdings Corp. will develop a new onshore wind power project in Albay after securing a permit from the Department of Energy (DoE). The DoE awarded a Certificate of Authority (CoA) to Alternergy Wind Holdings Corp. (AWHC), the wind sub-holding company of Alternergy, allowing it to undertake the exploration and assessment of [&#8230;]'),
#  ('url',
#   'https://www.bworldonline.com/corporate/2025/03/28/662340/alternergy-to-develop-wind-power-project-in-albay/'),
#  ('source', 'Business World'),
#  ('image',
#   'https://www.bworldonline.com/wp-content/uploads/2025/03/Wind-farm-renewable-energy-300x200.jpg'),
#  ('category', 'business'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:32+00:00'),
#  ('author', 'Associated Press'),
#  ('title',
#   'Valieva’s attorneys accuse WADA of ‘procedural fraud,’ ask court to revisit her doping case'),
#  ('description',
#   'By Eddie Pells Attorneys for Russian figure skater Kamila Valieva are taking her doping case back to court, arguing the World Anti-Doping Agency withheld and altered evidence that could have proven her contamination claim during the hearing that resulted in her four-year suspension. The experiment conducted by scientist Martial Saugy at the request of Russia&#8217;s [&#8230;]'),
#  ('url',
#   'https://winnipegsun.com/pmn/valievas-attorneys-accuse-wada-of-procedural-fraud-ask-court-to-revisit-her-doping-case'),
#  ('source', 'altonaecho'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:28+00:00'),
#  ('author', 'Claire James'),
#  ('title', 'Python Developers Lead Innovation in Finance and Data Analytics'),
#  ('description',
#   'Python has rapidly evolved from a general-purpose programming language to a cornerstone of modern finance and data analytics. Financial markets are increasingly data-oriented, automated, and AI-powered, and hence Python is the language of choice to develop sophisticated financial models, handle massive data, and design high-performing trading strategies. Its simplicity, flexibility, and wealth of libraries have [&#8230;]The post Python Developers Lead Innovation in Finance and Data Analytics appeared first on ABC Money.'),
#  ('url',
#   'https://www.abcmoney.co.uk/2025/03/python-developers-lead-innovation-in-finance-and-data-analytics/'),
#  ('source', 'ABC Money'),
#  ('image', None),
#  ('category', 'business'),
#  ('language', 'en'),
#  ('country', 'uk'),
#  ('published_at', '2025-03-27T16:09:25+00:00'),
#  ('author', 'neeraj kumar'),
#  ('title', 'Frauds target consumers with power cut threats'),
#  ('description',
#   'Thousands of electricity consumers, particularly in Hyderabad, have received fraudulent calls and messages from cybercriminals posing as power utility officials, warning them of imminent disconnection due to unpaid bills.'),
#  ('url',
#   'https://www.deccanchronicle.com/southern-states/telangana/frauds-target-consumers-with-power-cut-threats-1869376'),
#  ('source', 'deccanchronicle'),
#  ('image',
#   'https://www.deccanchronicle.com/h-upload/2025/03/27/1902158-powercut.webp'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:11+00:00'),
#  ('author', None),
#  ('title', 'Alvotech (ALVO) Q4 2024 Earnings Call Transcript'),
#  ('description', 'Alvotech (ALVO) Q4 2024 Earnings Call Transcript'),
#  ('url',
#   'https://seekingalpha.com/article/4770937-alvotech-alvo-q4-2024-earnings-call-transcript?source=feed_all_articles'),
#  ('source', 'Seeking Alpha'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:09+00:00'),
#  ('author', None),
#  ('title',
#   'Barriers to affordable housing found—research recommends establishing regional authority'),
#  ('description',
#   'A recent study published in the Journal of the American Planning Association has found significant challenges to including affordable housing in transit-oriented developments (TODs) in Southern California, despite state policies encouraging such integration.'),
#  ('url',
#   'https://phys.org/news/2025-03-barriers-housing-regional-authority.html'),
#  ('source', 'Phys.org - News And Articles On Science And Technology'),
#  ('image', 'https://scx1.b-cdn.net/csz/news/tmb/2025/affordable-housing.jpg'),
#  ('category', 'science'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:03+00:00'),
#  ('author', 'Alex Nelson'),
#  ('title',
#   'Sky redundancies: UK telecoms and media firm announces customer services job cuts – how it affects customers'),
#  ('description',
#   'The firm is making big changes to its customer service—what it means for you 📲'),
#  ('url',
#   'https://www.newsletter.co.uk/business/consumer/sky-redundancies-uk-telecoms-media-customer-services-job-cuts-5055052'),
#  ('source', 'newsletter'),
#  ('image',
#   'https://www.newsletter.co.uk/jpim-static/image/2025/03/27/15/16/pexels-yankrukov-8867429.jpeg?width=1200&auto=webp&crop=3%3A2'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'uk'),
#  ('published_at', '2025-03-27T16:09:02+00:00'),
#  ('author', 'Justin Baragona'),
#  ('title',
#   'Fox News star eviscerates Trump officials’ Signalgate excuses: ‘FAR MORE sensitive’ than ‘war plans’'),
#  ('description',
#   '‘This kind of real time operational information is more sensitive than ‘war plans,’ which makes this lapse more egregious, according to two former senior US defense officials,’ Jennifer Griffin reported on Wednesday'),
#  ('url',
#   'https://www.independent.co.uk/news/world/americas/us-politics/fox-news-signal-text-response-hegseth-b2722747.html'),
#  ('source', 'independent'),
#  ('image',
#   'https://static.independent.co.uk/2025/03/27/15/59/special-report-with-bret-baier-(1).jpg?width=1200&auto=webp&trim=0%2C50%2C0%2C50'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'uk'),
#  ('published_at', '2025-03-27T16:09:01+00:00'),
#  ('author', None),
#  ('title',
#   "Why I prefer this Lenovo tablet over the iPad for multimedia consumption (and it's $80 off)"),
#  ('description',
#   'The Lenovo Tab Plus delivers an impressive audio-visual experience with its powerful speaker system and sharp 2K display, surpassing some iPads in sound quality.'),
#  ('url',
#   'https://www.zdnet.com/article/why-i-prefer-this-lenovo-tablet-over-the-ipad-for-multimedia-consumption-and-its-80-off/'),
#  ('source', 'm'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:09:00+00:00'),
#  ('author', 'Jasper King'),
#  ('title',
#   'On-duty police officer caught on video urinating in woman’s front garden'),
#  ('description',
#   'The officer has talked to the professional standards department.'),
#  ('url',
#   'https://metro.co.uk/2025/03/27/on-duty-police-officer-caught-video-urinating-womans-front-garden-22800659/'),
#  ('source', 'Metro'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'gb'),
#  ('published_at', '2025-03-27T16:08:56+00:00'),
#  ('author', None),
#  ('title',
#   'Freehold Royalties Ltd. 2024 Q4 - Results - Earnings Call Presentation'),
#  ('description',
#   'Freehold Royalties Ltd. 2024 Q4 - Results - Earnings Call Presentation'),
#  ('url',
#   'https://seekingalpha.com/article/4770936-freehold-royalties-ltd-2024-q4-results-earnings-call-presentation?source=feed_all_articles'),
#  ('source', 'Seeking Alpha'),
#  ('image', None),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:08:54+00:00'),
#  ('author', None),
#  ('title', 'China willing to work with India on LAC issue: Military'),
#  ('description',
#   "China's military has said it is willing to work with India to find a solution to the border issue, while also pushing for sound and stable defence ties. The statement comes after recent meetings between officials from both countries to normalize relations following a prolonged period of tension."),
#  ('url',
#   'https://www.rediff.com/news/report/china-willing-to-work-with-india-on-border-issue-says-military/20250327.htm'),
#  ('source', 'rediff'),
#  ('image', '//im.rediff.com/news/2025/mar/27itbp-personnel-china-border.jpg'),
#  ('category', 'general'),
#  ('language', 'en'),
#  ('country', 'us'),
#  ('published_at', '2025-03-27T16:08:51+00:00')]

# %%
lista_fechas = lista_vacia[9::10]

# %%
lista_vacia_7 =[]
for i in lista_fechas:
    for fecha in i:
        lista_vacia_7.append(fecha)

# %%
noticias["fecha"]=lista_vacia_7[1::2]

# %%
noticias_df = pd.DataFrame(noticias)

# %%
noticias_df
# Out:
#                autor                                             titulo  \
# 0            AP News  Valieva’s attorneys accuse WADA of ‘procedural...
# 1   Andrew Liszewski  Audio-Technica’s R2-D2 earbuds play beeps and ...
# 2      Robert Cumber  Selling my house: 7 of the best ways to quickl...
# 3      Robert Cumber  Selling my house: 7 of the best ways to quickl...
# 4      Robert Cumber  Selling my house: 7 of the best ways to quickl...
# ..               ...                                                ...
# 95   Justin Baragona  Fox News star eviscerates Trump officials’ Sig...
# 96              None  Why I prefer this Lenovo tablet over the iPad ...
# 97       Jasper King  On-duty police officer caught on video urinati...
# 98              None  Freehold Royalties Ltd. 2024 Q4 - Results - Ea...
# 99              None  China willing to work with India on LAC issue:...
#
#                                           descripcion  \
# 0   Attorneys for Russian figure skater Kamila Val...
# 1   Audio-Technica is releasing four Star Wars-the...
# 2   There are some surprisingly easy ways to get y...
# 3   There are some surprisingly easy ways to get y...
# 4   There are some surprisingly easy ways to get y...
# ..                                                ...
# 95  ‘This kind of real time operational informatio...
# 96  The Lenovo Tab Plus delivers an impressive aud...
# 97  The officer has talked to the professional sta...
# 98  Freehold Royalties Ltd. 2024 Q4 - Results - Ea...
# 99  China's military has said it is willing to wor...
#
#                                                   url            fuente  \
# 0   https://www.mymotherlode.com/sports/top-sports...      mymotherlode
# 1   https://www.theverge.com/news/637222/audio-tec...         The Verge
# 2   https://www.harrogateadvertiser.co.uk/lifestyl...      ripongazette
# 3   https://www.sunderlandecho.com/lifestyle/homes...    sunderlandecho
# 4   https://www.sussexexpress.co.uk/lifestyle/home...  hastingsobserver
# ..                                                ...               ...
# 95  https://www.independent.co.uk/news/world/ameri...       independent
# 96  https://www.zdnet.com/article/why-i-prefer-thi...                 m
# 97  https://metro.co.uk/2025/03/27/on-duty-police-...             Metro
# 98  https://seekingalpha.com/article/4770936-freeh...     Seeking Alpha
# 99  https://www.rediff.com/news/report/china-willi...            rediff
#
#                         fecha
# 0   2025-03-27T16:14:47+00:00
# 1   2025-03-27T16:14:45+00:00
# 2   2025-03-27T16:14:43+00:00
# 3   2025-03-27T16:14:43+00:00
# 4   2025-03-27T16:14:43+00:00
# ..                        ...
# 95  2025-03-27T16:09:01+00:00
# 96  2025-03-27T16:09:00+00:00
# 97  2025-03-27T16:08:56+00:00
# 98  2025-03-27T16:08:54+00:00
# 99  2025-03-27T16:08:51+00:00
#
# [100 rows x 6 columns]
